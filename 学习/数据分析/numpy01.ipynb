# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif'] = ['KaiTi']
plt.rcParams['axes.unicode_minus'] = False

# %%
x_1 = np.random.normal(1.25, 2, 10000)

# %%
plt.figure(figsize=(20, 8))
plt.hist(x_1)
# Out:
# (array([  35.,  191.,  865., 1922., 2817., 2476., 1255.,  366.,   68.,
#            5.]),
#  array([-5.64649232, -4.17939857, -2.71230481, -1.24521106,  0.22188269,
#          1.68897644,  3.15607019,  4.62316395,  6.0902577 ,  7.55735145,
#          9.0244452 ]),
#  <BarContainer object of 10 artists>)

# %%
x_2 = np.random.randint(1, 10000, size=(10, 2))
x_3 = np.random.uniform(1, 1000, size=(10, 2))
x_3
# Out:
# array([[620.01115098,  53.93863499],
#        [365.92320595, 970.15951003],
#        [ 69.03804165, 955.21045686],
#        [807.38462099, 325.48706995],
#        [ 22.97627704, 679.09841659],
#        [822.31592574, 779.17128892],
#        [272.87502893, 373.32804275],
#        [778.75684623, 959.4650523 ],
#        [491.88009568,   9.62463273],
#        [559.26412186, 247.29881849]])
