# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif'] = ['KaiTi']
plt.rcParams['axes.unicode_minus'] = False

# %%
x_1 = np.random.rand(10)
y_1 = np.random.uniform(-1, 1, 10)

plt.figure(figsize=(20, 8))
plt.scatter(x_1, y_1)
plt.plot(x_1, y_1)

# %%
array_1 = np.random.randint(1, 5, size=(2, 3))
array_1.reshape((3, 2))

# 没东西, 基于源对象修改
arr_2 = array_1.resize((3, 2))
array_1

# %%
arr_3 = np.random.randint(1, 4, size=(3, 4))
arr_3
arr_3.flatten()
arr_3
arr_3.ravel()
print(arr_3)
# Out:
# [[1 2 2 2]
#  [3 1 2 2]
#  [3 2 2 2]]

# %% [markdown]
# ### 行列转置

# %%
arr_3 = np.random.randint(0, 5, size=(2, 3))
arr_3
# Out:
# array([[0, 1, 0],
#        [1, 0, 4]])

# %%
arr_3.T
# Out:
# array([[0, 1, 0],
#        [1, 0, 4]])

# %%
np_1 = np.arange(20).reshape((4, 5))
np.hsplit(np_1, [1, 2, 3])
# Out:
# [array([[ 0],
#         [ 5],
#         [10],
#         [15]]),
#  array([[ 1],
#         [ 6],
#         [11],
#         [16]]),
#  array([[ 2],
#         [ 7],
#         [12],
#         [17]]),
#  array([[ 3,  4],
#         [ 8,  9],
#         [13, 14],
#         [18, 19]])]
